# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import ndimage
img = ndimage.imread("2019212257.jpg")
plt.figure(figsize = (10,7))
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wk/y2f0j6193x7261zt_mxhmzp80000gn/T/ipykernel_2340/4078515677.py in <module>
#       2 import matplotlib.pyplot as plt
#       3 from scipy import ndimage
# ----> 4 img = ndimage.imread("2019212257.jpg")
#       5 plt.figure(figsize = (10,7))
#       6 plt.imshow(img)
#
# AttributeError: module 'scipy.ndimage' has no attribute 'imread'

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.7.1

# %% [markdown]
# ### since scipy 1.2,  imread is no longer supported. Junwei is trying the following solution

# %%
import imageio
img = imageio.imread('2019212257.jpg')
img.shape  # im is a numpy array
(512, 512, 3)
# Out:
# (512, 512, 3)

# %%
plt.figure(figsize = (10,7))
plt.imshow(img)

# %%
x,y,z = img.shape
long_img = img.reshape(x* y,z)
long_img.shape
# Out:
# (259200, 3)

# %%
from sklearn import cluster
k_means = cluster.KMeans(n_clusters=5)
k_means.fit(long_img)
centers = k_means.cluster_centers_
centers
# Out:
# array([[189.84029293, 197.60180628, 200.02304362],
#        [ 23.05412694,  22.81117621,  23.93507392],
#        [142.26826626, 118.69425337, 107.04760873],
#        [218.2628022 , 171.4082967 , 142.15763736],
#        [ 81.8449707 ,  62.78725586,  56.34130859]])

# %%
labels = k_means.labels_
labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
plt.figure(figsize = (10,7))
plt.imshow(centers[labels].reshape(x,y, z).astype(int))
